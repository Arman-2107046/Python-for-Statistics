# %% [markdown]
# FIFA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
fifa=pd.read_csv('fifa_data.csv')
# fifa
# fifa.head(5)

# %% [markdown]
# Histograms

# %%
bins=np.arange(40,110,10)


plt.hist(fifa.Overall, bins=bins)


plt.xticks(bins)

plt.xlabel("Skill Level")
plt.ylabel("Number of Players")
plt.title('Distribution of Players Skills in FIFA', fontdict={'fontweight':'bold', 'fontsize':18})


plt.show()

# %% [markdown]
# Pie Charts

# %%
# fifa.head(5)
# fifa['Preferred Foot']

left=fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
right=fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]
# print(right)
labels=['Left','Right']

plt.pie([left,right],labels=labels, autopct='%.2f %%')
plt.title('Foot Preference of FIFA Players')
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3264\3080464227.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   left=fifa.loc[fifa['Preferred Foot']=='Left'].count()[0]
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3264\3080464227.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   right=fifa.loc[fifa['Preferred Foot']=='Right'].count()[0]

# %%
fifa.Weight = [int(x.strip("lbs")) if type(x) == str else x for x in fifa.Weight]

plt.style.use('ggplot')

# fifa.Weight

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa.loc[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa.loc[(fifa.Weight > 200)].count()[0]


weights=[light, light_medium, medium, medium_heavy, heavy]
labels=['Under 125', '125-150','150-175','175-200','Over 200']
explode=[.4,0.2,0,0,.4]

plt.title("Weight Distribution of FIFA Players")
plt.pie(weights, labels=labels, autopct='%.2f %%', pctdistance=1, explode=explode)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3264\2237736887.py:7: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light = fifa.loc[fifa.Weight < 125].count()[0]
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3264\2237736887.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
# ...

# %% [markdown]
# BOXPLOT

# %%
plt.style.use('default')

barcelona=fifa.loc[fifa.Club=='FC Barcelona']['Overall']
madrid=fifa.loc[fifa.Club=='Real Madrid']['Overall']
labels=['FC Barcelona','Real Madrid']
plt.boxplot([barcelona,madrid],labels=labels)

plt.title("FC Barcelona Vs Real Madrid")
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_3264\905275756.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([barcelona,madrid],labels=labels)
