# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

sns.catplot(
    data=df,
    x='age',
    y='class',
    kind='violin',
    hue='alive'
    )
# sns.catplot(
#     data=df,
#     x='age',
#     kind='swarm')


plt.show()
