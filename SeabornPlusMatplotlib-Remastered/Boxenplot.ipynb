# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('taxis')

# sns.catplot(data=df,x='total',kind='box' )
sns.catplot(data=df,
            x='total',
            kind='boxen',
            hue='payment',
            col='color',
            gap=0.2)


plt.show()
