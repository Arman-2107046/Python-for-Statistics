# %% [markdown]
# SCATTERPLOT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('tips')
# df.to_csv('tips.csv')

# %%
df = sns.load_dataset('tips')

# Define a palette with different shades of slate
slate_palette = ['#6a5acd', '#7b68ee', '#8470ff', '#9370db', '#9966cc', '#a285e0']

sns.relplot(data=df, x='total_bill', y='tip', col='day',row='sex' , hue='sex')
plt.show()

# %% [markdown]
# LINEPLOT
