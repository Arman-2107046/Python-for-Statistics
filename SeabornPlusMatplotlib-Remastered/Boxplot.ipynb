# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=sns.load_dataset('titanic')
# df.to_csv('titanic.csv')

# %%
sns.catplot(
    data=df,
    x='age',
    y='class',
    kind='box',
    fill=False,
    hue='alive',
    gap=0.2,
    col='alone',
    row='who')

# sns.stripplot(data=df, x='age',y='class')


plt.show()
